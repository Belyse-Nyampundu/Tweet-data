# %%
import nltk

# %% [raw]
# nltk is the most popular python package

# %%
nltk.download("movie_reviews")
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /home/oem/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %% [raw]
# Once the data have been downloaded, we can import them from nltk.corpus
# and also if you don't want to specify the movie_reviews you can download the one you want by typing
# nltk.download()

# %%
from nltk.corpus import movie_reviews

# %% [raw]
# The fields method provided by all the datasets in nltk.corpus gives access to a list of all files availabale.
#
# In particular in the movie reviews

# %%
len(movie_reviews.fileids())
# Out:
# 2000

# %%
negative_fileids = movie_reviews.fileids('neg')
positive_fileids = movie_reviews.fileids('pos')

# %%
len(negative_fileids), len(positive_fileids)
# Out:
# (1000, 1000)

# %% [raw]
# we can inspect one of the reviews using the raw method of movie_reviews, each file is split into sentences,the curators of this dataset also removed from each review from any direct mention of the rating of the movie.

# %%
print(movie_reviews.raw(fileids=positive_fileids[0]))
# Out:
# films adapted from comic books have had plenty of success , whether they're about superheroes ( batman , superman , spawn ) , or geared toward kids ( casper ) or the arthouse crowd ( ghost world ) , but there's never really been a comic book like from hell before .
# for starters , it was created by alan moore ( and eddie campbell ) , who brought the medium to a whole new level in the mid '80s with a 12-part series called the watchmen .
# to say moore and campbell thoroughly researched the subject of jack the ripper would be like saying michael jackson is starting to look a little odd .
# the book ( or " graphic novel , " if you will ) is over 500 pages long and includes nearly 30 more that consist of nothing but footnotes .
# in other words , don't dismiss this film because of its source .
# if you can get past the whole comic book thing , you might find another stumbling block in from hell's directors , albert and allen hughes .
# ...

# %% [raw]
# TOKENIZE TEXT IN WORDS:Trying to determin what word is important word or relevant word

# %%
romeo_text = """ of course , whitechapel in 1888 london's east end . 
it's a filthy , sooty place where the whores ( called " unfortunates " ) are starting to get a little nervous about this mysterious
psychopath who has been carving through their profession with surgical precision . """

# %% [raw]
# The first step in Natural Language processing is generally to split the text into words,this process might appear simple but it is very tedious to handle all corner cases,
# see for example all the issue with p

# %%
romeo_text.split()
# Out:
# ['of',
#  'course',
#  ',',
#  'whitechapel',
#  'in',
#  '1888',
#  "london's",
#  'east',
#  'end',
#  '.',
#  "it's",
#  'a',
#  'filthy',
#  ',',
#  'sooty',
#  'place',
#  'where',
#  'the',
#  'whores',
#  '(',
#  'called',
#  '"',
#  'unfortunates',
#  '"',
#  ')',
#  'are',
#  'starting',
#  'to',
#  'get',
#  'a',
#  'little',
#  'nervous',
#  'about',
#  'this',
#  'mysterious',
#  'psychopath',
#  'who',
#  'has',
#  'been',
#  'carving',
#  'through',
#  'their',
#  'profession',
#  'with',
#  'surgical',
#  'precision',
#  '.']

# %% [raw]
# Tokenizing is like creating tokens,is one way of cleaning

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/oem/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [raw]
# Then we can use the word_tokenize function to properly tokenize this text, compare to the whitespace splitting we used above

# %%
romeo_words = nltk.word_tokenize(romeo_text)

# %%
romeo_words
# Out:
# ['of',
#  'course',
#  ',',
#  'whitechapel',
#  'in',
#  '1888',
#  'london',
#  "'s",
#  'east',
#  'end',
#  '.',
#  'it',
#  "'s",
#  'a',
#  'filthy',
#  ',',
#  'sooty',
#  'place',
#  'where',
#  'the',
#  'whores',
#  '(',
#  'called',
#  '``',
#  'unfortunates',
#  '``',
#  ')',
#  'are',
#  'starting',
#  'to',
#  'get',
#  'a',
#  'little',
#  'nervous',
#  'about',
#  'this',
#  'mysterious',
#  'psychopath',
#  'who',
#  'has',
#  'been',
#  'carving',
#  'through',
#  'their',
#  'profession',
#  'with',
#  'surgical',
#  'precision',
#  '.']

# %% [raw]
# Build a bag of world model
#
# The simplest model for analyzing text is just to think about text as an unorderd collection of words(bag-of-word)

# %%
{word:True for word in romeo_words}
# Out:
# {'of': True,
#  'course': True,
#  ',': True,
#  'whitechapel': True,
#  'in': True,
#  '1888': True,
#  'london': True,
#  "'s": True,
#  'east': True,
#  'end': True,
#  '.': True,
#  'it': True,
#  'a': True,
#  'filthy': True,
#  'sooty': True,
#  'place': True,
#  'where': True,
#  'the': True,
#  'whores': True,
#  '(': True,
#  'called': True,
#  '``': True,
#  'unfortunates': True,
#  ')': True,
#  'are': True,
#  'starting': True,
#  'to': True,
#  'get': True,
#  'little': True,
#  'nervous': True,
#  'about': True,
#  'this': True,
#  'mysterious': True,
#  'psychopath': True,
#  'who': True,
#  'has': True,
#  'been': True,
#  'carving': True,
#  'through': True,
#  'their': True,
#  'profession': True,
#  'with': True,
#  'surgical': True,
#  'precision': True}

# %%
type(_)
# Out:
# dict

# %%
def build_bag_of_words_features(words):
    return {word:True for word in words}

# %%
build_bag_of_words_features(romeo_words)
# Out:
# {'of': True,
#  'course': True,
#  ',': True,
#  'whitechapel': True,
#  'in': True,
#  '1888': True,
#  'london': True,
#  "'s": True,
#  'east': True,
#  'end': True,
#  '.': True,
#  'it': True,
#  'a': True,
#  'filthy': True,
#  'sooty': True,
#  'place': True,
#  'where': True,
#  'the': True,
#  'whores': True,
#  '(': True,
#  'called': True,
#  '``': True,
#  'unfortunates': True,
#  ')': True,
#  'are': True,
#  'starting': True,
#  'to': True,
#  'get': True,
#  'little': True,
#  'nervous': True,
#  'about': True,
#  'this': True,
#  'mysterious': True,
#  'psychopath': True,
#  'who': True,
#  'has': True,
#  'been': True,
#  'carving': True,
#  'through': True,
#  'their': True,
#  'profession': True,
#  'with': True,
#  'surgical': True,
#  'precision': True}

# %% [raw]
# build_bag_of_words_features(romeon_words)

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /home/oem/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
useless_words = nltk.corpus.stopwords.words("english")+list(string.punctuation)
useless_words
print(useless_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %% [raw]
# you can add emoji code to remove the emoji

# %%
def build_bag_of_words_features_filtered(words):
    return{
        word:1 for word in words  
        if not word in useless_words}

# %%
build_bag_of_words_features_filtered(romeo_words)
# Out:
# {'course': 1,
#  'whitechapel': 1,
#  '1888': 1,
#  'london': 1,
#  "'s": 1,
#  'east': 1,
#  'end': 1,
#  'filthy': 1,
#  'sooty': 1,
#  'place': 1,
#  'whores': 1,
#  'called': 1,
#  '``': 1,
#  'unfortunates': 1,
#  'starting': 1,
#  'get': 1,
#  'little': 1,
#  'nervous': 1,
#  'mysterious': 1,
#  'psychopath': 1,
#  'carving': 1,
#  'profession': 1,
#  'surgical': 1,
#  'precision': 1}

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
romeo_words = """ of course , whitechapel in 1888 london's east end . 
it's a filthy , sooty place where the whores ( called " unfortunates " ) are starting to get a little nervous about this mysterious
psychopath who has been carving through their profession with surgical precision . """
# create a word cloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(romeo_words)

# Dispaly the generated wordcloud

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [raw]
# Plotting frequencies of Words

# %%
all_words = movie_reviews.words()
len(all_words)/1e6
# Out:
# 1.58382

# %% [raw]
# First we want to filter out useless_words as defined in the previous section this will reduce the length
# of the dataset by more than a factor of 2

# %%
filtered_words = [word for word in movie_reviews.words()
                  if not word in useless_words]
type(filtered_words)
# Out:
# list

# %%
len(filtered_words)/1e6
# Out:
# 0.710579

# %% [raw]
# The collection package of the standard library contains a Counter class that is handy for counting frequencies
# of words in our list:

# %%
from collections import Counter

# %%
word_counter = Counter(filtered_words)

# %% [raw]
# It also has a most- common() method to access the words with higher count

# %%
most_common_words = word_counter.most_common()[:10]

# %%
most_common_words
# Out:
# [('film', 9517),
#  ('one', 5852),
#  ('movie', 5771),
#  ('like', 3690),
#  ('even', 2565),
#  ('good', 2411),
#  ('time', 2411),
#  ('story', 2169),
#  ('would', 2109),
#  ('much', 2049)]

# %% [raw]
# Then wwe will visualize this using matplot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [raw]
# We can sort the word count and plot their values on Logarithmic axes to check of the distribution. This visualization is particularly useful if comparing 2 or
# more datasets a flatter distribution indicates a lare vacabulary while a peaked distribution a restricted vocabulary often due to a focused topic or specialized language

# %%
sorted_word_counts = sorted(list(word_counter.values()), reverse=True)

plt.loglog(sorted_word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5, 0, 'Word Rank')

# %%
plt.hist(sorted_word_counts, bins=50);

# %%
plt.hist(sorted_word_counts, bins=50, log=True)
# Out:
# (array([3.897e+04, 3.610e+02, 1.170e+02, 4.300e+01, 4.000e+01, 1.500e+01,
#         9.000e+00, 8.000e+00, 5.000e+00, 4.000e+00, 6.000e+00, 2.000e+00,
#         2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([1.00000e+00, 1.91320e+02, 3.81640e+02, 5.71960e+02, 7.62280e+02,
#         9.52600e+02, 1.14292e+03, 1.33324e+03, 1.52356e+03, 1.71388e+03,
#         1.90420e+03, 2.09452e+03, 2.28484e+03, 2.47516e+03, 2.66548e+03,
#         2.85580e+03, 3.04612e+03, 3.23644e+03, 3.42676e+03, 3.61708e+03,
# ...

# %% [raw]
# Sentiment Analysis

# %%
negative_features = [
(build_bag_of_words_features_filtered(movie_reviews.words(fileids=[f])), 'neg') \
for f in negative_fileids
 
 ]

# %%
print(negative_features[3])
# Out:
# ({'quest': 1, 'camelot': 1, 'warner': 1, 'bros': 1, 'first': 1, 'feature': 1, 'length': 1, 'fully': 1, 'animated': 1, 'attempt': 1, 'steal': 1, 'clout': 1, 'disney': 1, 'cartoon': 1, 'empire': 1, 'mouse': 1, 'reason': 1, 'worried': 1, 'recent': 1, 'challenger': 1, 'throne': 1, 'last': 1, 'fall': 1, 'promising': 1, 'flawed': 1, '20th': 1, 'century': 1, 'fox': 1, 'production': 1, 'anastasia': 1, 'hercules': 1, 'lively': 1, 'cast': 1, 'colorful': 1, 'palate': 1, 'beat': 1, 'hands': 1, 'came': 1, 'time': 1, 'crown': 1, '1997': 1, 'best': 1, 'piece': 1, 'animation': 1, 'year': 1, 'contest': 1, 'pretty': 1, 'much': 1, 'dead': 1, 'arrival': 1, 'even': 1, 'magic': 1, 'kingdom': 1, 'mediocre': 1, '--': 1, 'pocahontas': 1, 'keeping': 1, 'score': 1, 'nearly': 1, 'dull': 1, 'story': 1, 'revolves': 1, 'around': 1, 'adventures': 1, 'free': 1, 'spirited': 1, 'kayley': 1, 'voiced': 1, 'jessalyn': 1, 'gilsig': 1, 'early': 1, 'teen': 1, 'daughter': 1, 'belated': 1, 'knight': 1, 'king': 1, 'arthur': 1,
# ...

# %%
positive_features =[ (build_bag_of_words_features_filtered(movie_reviews.words(fileids=[f])), 'pos') \
for f in positive_fileids
 ]

# %%
print(positive_features[6])
# Out:
# ({'apparently': 1, 'director': 1, 'tony': 1, 'kaye': 1, 'major': 1, 'battle': 1, 'new': 1, 'line': 1, 'regarding': 1, 'film': 1, 'american': 1, 'history': 1, 'x': 1, 'know': 1, 'details': 1, 'fight': 1, 'seems': 1, 'happy': 1, 'final': 1, 'product': 1, 'nearly': 1, 'removed': 1, 'name': 1, 'credits': 1, 'altogether': 1, 'heard': 1, 'kind': 1, 'thing': 1, 'happening': 1, 'makes': 1, 'wonder': 1, 'much': 1, 'input': 1, 'studio': 1, 'films': 1, 'produce': 1, 'found': 1, 'extremely': 1, 'good': 1, 'focused': 1, 'look': 1, 'touchy': 1, 'subject': 1, 'racism': 1, 'powerful': 1, 'charismatic': 1, 'performance': 1, 'edward': 1, 'norton': 1, 'hard': 1, 'believe': 1, 'two': 1, 'years': 1, 'since': 1, 'fantastic': 1, 'role': 1, 'primal': 1, 'fear': 1, 'starring': 1, 'making': 1, 'star': 1, 'one': 1, 'performers': 1, 'becomes': 1, 'character': 1, 'work': 1, 'best': 1, 'performances': 1, 'year': 1, 'plays': 1, 'young': 1, 'man': 1, 'named': 1, 'derek': 1, 'vinyard': 1, 'skinhead': 1, 'living': 1,
# ...

# %%
from nltk.classify import NaiveBayesClassifier

# %% [raw]
# Naive Bayes

# %%
split = 800

# %%
sentiment_classifier = NaiveBayesClassifier.train(positive_features[:split]+negative_features[:split])

# %%
nltk.classify.util.accuracy
(sentiment_classifier, positive_features[:split]+negative_features[:split])*100

# %%
# nltk.classify.util.accuracy
# (sentiment_classifier, positive_features[split:]+negative_features[split:])*100

# %%
# sentiment_classifier.show_most_informative_features()
