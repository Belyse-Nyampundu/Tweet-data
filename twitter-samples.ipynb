# %%
import nltk

# %%
nltk.download("twitter_samples")
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/oem/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
from nltk.corpus import twitter_samples

# %%
len(twitter_samples.fileids())
# Out:
# 3

# %%
negative_fileids = twitter_samples.strings('negative_tweets.json')
positive_fileids = twitter_samples.strings('positive_tweets.json')

# %%
print(negative_fileids)
# Out:
# ['hopeless for tmr :(', "Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(", '@Hegelbon That heart sliding into the waste basket. :(', '“@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too', 'Dang starting next week I have "work" :(', "oh god, my babies' faces :( https://t.co/9fcwGvaki0", '@RileyMcDonough make me smile :((', '@f0ggstar @stuartthull work neighbour on motors. Asked why and he said hates the updates on search :( http://t.co/XvmTUikWln', 'why?:("@tahuodyy: sialan:( https://t.co/Hv1i0xcrL2"', 'Athabasca glacier was there in #1948 :-( #athabasca #glacier #jasper #jaspernationalpark #alberta #explorealberta #… http://t.co/dZZdqmf7Cz', "I have a really good m&amp;g idea but I'm never going to meet them :(((", '@Rampageinthebox mare ivan :(', '@SophiaMascardo happy trip, keep safe. see you soon :* :(', "I'm so tired hahahah :(", '@GrumpyCockney With knee replacements they get you up &amp; about the same day. :-(   Ouch.', 'relat
# ...

# %%
twitter_text = """ It just doesn't go away... you must go to the dentist. :( #poorKid", "@denocte Thanks - lack of time is a problem, isn't it :(", 'When you get misunderstood :(', 'when ur cat is super nice and cuddly but then suddenly scratches and tries to bite :( \n\nlike who can i trust anymore', 'I hit my thumb :(.', '@iloveksoo we almost got to see his cute ankles but his socks :(', "@bravefrontiergl Honestly at this point I don't care about compensation. I just want to be able to play BF again. :(", '@dnwrld that song is not on here :(', '@CourtneyR_Green awwwww my baby"""

# %%
twitter_text.split()
# Out:
# ['It',
#  'just',
#  "doesn't",
#  'go',
#  'away...',
#  'you',
#  'must',
#  'go',
#  'to',
#  'the',
#  'dentist.',
#  ':(',
#  '#poorKid",',
#  '"@denocte',
#  'Thanks',
#  '-',
#  'lack',
#  'of',
#  'time',
#  'is',
#  'a',
#  'problem,',
#  "isn't",
#  'it',
#  ':(",',
#  "'When",
#  'you',
#  'get',
#  'misunderstood',
#  ":(',",
#  "'when",
#  'ur',
#  'cat',
#  'is',
#  'super',
#  'nice',
#  'and',
#  'cuddly',
#  'but',
#  'then',
#  'suddenly',
#  'scratches',
#  'and',
#  'tries',
#  'to',
#  'bite',
#  ':(',
#  'like',
#  'who',
#  'can',
#  'i',
#  'trust',
#  "anymore',",
#  "'I",
#  'hit',
#  'my',
#  'thumb',
#  ":(.',",
#  "'@iloveksoo",
#  'we',
#  'almost',
#  'got',
#  'to',
#  'see',
#  'his',
#  'cute',
#  'ankles',
#  'but',
#  'his',
#  'socks',
#  ":(',",
#  '"@bravefrontiergl',
#  'Honestly',
#  'at',
#  'this',
#  'point',
#  'I',
#  "don't",
#  'care',
#  'about',
#  'compensation.',
#  'I',
#  'just',
#  'want',
#  'to',
#  'be',
#  'able',
#  'to',
# ...

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/oem/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
twitter_words = nltk.word_tokenize(twitter_text)

# %%
twitter_words
# Out:
# ['It',
#  'just',
#  'does',
#  "n't",
#  'go',
#  'away',
#  '...',
#  'you',
#  'must',
#  'go',
#  'to',
#  'the',
#  'dentist',
#  '.',
#  ':',
#  '(',
#  '#',
#  'poorKid',
#  "''",
#  ',',
#  '``',
#  '@',
#  'denocte',
#  'Thanks',
#  '-',
#  'lack',
#  'of',
#  'time',
#  'is',
#  'a',
#  'problem',
#  ',',
#  'is',
#  "n't",
#  'it',
#  ':',
#  '(',
#  '``',
#  ',',
#  "'When",
#  'you',
#  'get',
#  'misunderstood',
#  ':',
#  '(',
#  "'",
#  ',',
#  "'when",
#  'ur',
#  'cat',
#  'is',
#  'super',
#  'nice',
#  'and',
#  'cuddly',
#  'but',
#  'then',
#  'suddenly',
#  'scratches',
#  'and',
#  'tries',
#  'to',
#  'bite',
#  ':',
#  '(',
#  'like',
#  'who',
#  'can',
#  'i',
#  'trust',
#  'anymore',
#  "'",
#  ',',
#  "'",
#  'I',
#  'hit',
#  'my',
#  'thumb',
#  ':',
#  '(',
#  '.',
#  "'",
#  ',',
#  "'",
#  '@',
#  'iloveksoo',
#  'we',
#  'almost',
#  'got',
#  'to',
#  'see',
#  'his',
#  'cute',
#  'ankles',
#  'but',
#  'his',
#  'socks',
#  ':',
#  '(',
# ...

# %%
{word:True for word in twitter_words}
# Out:
# {'It': True,
#  'just': True,
#  'does': True,
#  "n't": True,
#  'go': True,
#  'away': True,
#  '...': True,
#  'you': True,
#  'must': True,
#  'to': True,
#  'the': True,
#  'dentist': True,
#  '.': True,
#  ':': True,
#  '(': True,
#  '#': True,
#  'poorKid': True,
#  "''": True,
#  ',': True,
#  '``': True,
#  '@': True,
#  'denocte': True,
#  'Thanks': True,
#  '-': True,
#  'lack': True,
#  'of': True,
#  'time': True,
#  'is': True,
#  'a': True,
#  'problem': True,
#  'it': True,
#  "'When": True,
#  'get': True,
#  'misunderstood': True,
#  "'": True,
#  "'when": True,
#  'ur': True,
#  'cat': True,
#  'super': True,
#  'nice': True,
#  'and': True,
#  'cuddly': True,
#  'but': True,
#  'then': True,
#  'suddenly': True,
#  'scratches': True,
#  'tries': True,
#  'bite': True,
#  'like': True,
#  'who': True,
#  'can': True,
#  'i': True,
#  'trust': True,
#  'anymore': True,
#  'I': True,
#  'hit': True,
#  'my': True,
#  'thumb': True,
#  'iloveksoo': True,
# ...

# %%
type(_)
# Out:
# dict

# %%
def build_bag_of_words_features(words):
    return {word:True for word in words}

# %%
build_bag_of_words_features(twitter_words)
# Out:
# {'It': True,
#  'just': True,
#  'does': True,
#  "n't": True,
#  'go': True,
#  'away': True,
#  '...': True,
#  'you': True,
#  'must': True,
#  'to': True,
#  'the': True,
#  'dentist': True,
#  '.': True,
#  ':': True,
#  '(': True,
#  '#': True,
#  'poorKid': True,
#  "''": True,
#  ',': True,
#  '``': True,
#  '@': True,
#  'denocte': True,
#  'Thanks': True,
#  '-': True,
#  'lack': True,
#  'of': True,
#  'time': True,
#  'is': True,
#  'a': True,
#  'problem': True,
#  'it': True,
#  "'When": True,
#  'get': True,
#  'misunderstood': True,
#  "'": True,
#  "'when": True,
#  'ur': True,
#  'cat': True,
#  'super': True,
#  'nice': True,
#  'and': True,
#  'cuddly': True,
#  'but': True,
#  'then': True,
#  'suddenly': True,
#  'scratches': True,
#  'tries': True,
#  'bite': True,
#  'like': True,
#  'who': True,
#  'can': True,
#  'i': True,
#  'trust': True,
#  'anymore': True,
#  'I': True,
#  'hit': True,
#  'my': True,
#  'thumb': True,
#  'iloveksoo': True,
# ...

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /home/oem/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
useless_words = nltk.corpus.stopwords.words("english")+list(string.punctuation)
useless_words
print(useless_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
def build_bag_of_words_features_filtered(words):
    return{
        word:1 for word in words  
        if not word in useless_words}

# %%
build_bag_of_words_features_filtered(twitter_words)
# Out:
# {'It': 1,
#  "n't": 1,
#  'go': 1,
#  'away': 1,
#  '...': 1,
#  'must': 1,
#  'dentist': 1,
#  'poorKid': 1,
#  "''": 1,
#  '``': 1,
#  'denocte': 1,
#  'Thanks': 1,
#  'lack': 1,
#  'time': 1,
#  'problem': 1,
#  "'When": 1,
#  'get': 1,
#  'misunderstood': 1,
#  "'when": 1,
#  'ur': 1,
#  'cat': 1,
#  'super': 1,
#  'nice': 1,
#  'cuddly': 1,
#  'suddenly': 1,
#  'scratches': 1,
#  'tries': 1,
#  'bite': 1,
#  'like': 1,
#  'trust': 1,
#  'anymore': 1,
#  'I': 1,
#  'hit': 1,
#  'thumb': 1,
#  'iloveksoo': 1,
#  'almost': 1,
#  'got': 1,
#  'see': 1,
#  'cute': 1,
#  'ankles': 1,
#  'socks': 1,
#  'bravefrontiergl': 1,
#  'Honestly': 1,
#  'point': 1,
#  'care': 1,
#  'compensation': 1,
#  'want': 1,
#  'able': 1,
#  'play': 1,
#  'BF': 1,
#  'dnwrld': 1,
#  'song': 1,
#  'CourtneyR_Green': 1,
#  'awwwww': 1,
#  'baby': 1}

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
twitter_words = """  It just doesn't go away... you must go to the dentist. :( #poorKid", "@denocte Thanks - lack of time is a problem, isn't it :(", 'When you get misunderstood :(', 'when ur cat is super nice and cuddly but then suddenly scratches and tries to bite :( \n\nlike who can i trust anymore', 'I hit my thumb :(.', '@iloveksoo we almost got to see his cute ankles but his socks :(', "@bravefrontiergl Honestly at this point I don't care about compensation. I just want to be able to play BF again. :(", '@dnwrld that song is not on here :(', '@CourtneyR_Green awwwww my baby """
# create a word cloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(twitter_words)

# Dispaly the generated wordcloud

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
all_words = twitter_samples.strings()
len(all_words)/1e6
# Out:
# 0.03

# %%
filtered_words = [strings for strings in twitter_samples.strings()
                  if not strings in useless_words]
type(filtered_words)
# Out:
# list

# %%
len(filtered_words)/1e6
# Out:
# 0.03

# %%
from collections import Counter

# %%
word_counter = Counter(filtered_words)

# %%
most_common_words = word_counter.most_common()[:10]

# %%
most_common_words
# Out:
# [('RT @Tommy_Colc: Financial Times come out in support of Tories claiming Miliband is "preoccupied w/ inequality". The man who wrote it http:/…',
#   491),
#  ('RT @NicolaSturgeon: If Miliband is going to let Tories in rather than work with SNP, we will definitely need lots of SNP MPs to protect Sco…',
#   430),
#  ('RT @Tommy_Colc: FT come out in support of Tories claiming Miliband is "preoccupied w/ inequality". The man who wrote it @sturdyAlex http://…',
#   131),
#  ('RT @thomasmessenger: For all Tories claiming that Labour overspent and thus caused a global financial crisis, ahem... http://t.co/DkLwCwzhDA',
#   131),
#  ("RT @abstex: The FT is backing the Tories. On an unrelated note, here's a photo of FT leader writer Jonathan Ford (next to Boris) http://t.c…",
#   117),
#  ("RT @mrmarksteel: Tomorrow Miliband will say 'let me tell you this, I'm not even voting for myself in case I do a deal with the SNP'.",
#   103),
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
sorted_word_counts = sorted(list(word_counter.values()), reverse=True)

plt.loglog(sorted_word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5, 0, 'Word Rank')

# %%
plt.hist(sorted_word_counts, bins=50);

# %%
plt.hist(sorted_word_counts, bins=50, log=True)
# Out:
# (array([2.0196e+04, 1.4900e+02, 3.7000e+01, 9.0000e+00, 8.0000e+00,
#         4.0000e+00, 5.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([  1. ,  10.8,  20.6,  30.4,  40.2,  50. ,  59.8,  69.6,  79.4,
#          89.2,  99. , 108.8, 118.6, 128.4, 138.2, 148. , 157.8, 167.6,
#         177.4, 187.2, 197. , 206.8, 216.6, 226.4, 236.2, 246. , 255.8,
#         265.6, 275.4, 285.2, 295. , 304.8, 314.6, 324.4, 334.2, 344. ,
# ...

# %%
negative_features = [
(build_bag_of_words_features_filtered(twitter_samples.strings(fileids=[f])), 'positive_tweets.json') \
for f in positive_fileids
 
 ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 negative_features = [
#       2 (build_bag_of_words_features_filtered(twitter_samples.strings(fileids=[f])), 'positive_tweets.json') \
# ----> 3 for f in positive_fileids
#       4
#       5  ]
#
# NameError: name 'positive_fileids' is not defined
